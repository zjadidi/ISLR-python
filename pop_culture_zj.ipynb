# %% [markdown]
# <a href="https://colab.research.google.com/github/zjadidi/ISLR-python/blob/master/pop_culture_zj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# Edit this however you like, then run this cell
message = "Hello from my first GitHub commit!"
print(message)
# Out:
# Hello from my first GitHub commit!
